# %% [markdown]
# <a href="https://colab.research.google.com/github/cvre12345/Google-Colab-Projects/blob/main/CK_15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#class 15
#how many people survived 7
#what factor effected the survival

import pandas as pd

# load dataset
df = pd.read_csv("titanic.csv")

# first 5 rows
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-626558039.py in <cell line: 0>()
#       6
#       7 # load dataset
# ----> 8 df = pd.read_csv("titanic.csv")
#       9
#      10 # first 5 rows
#
# ...

# %%
# dataset information
print(df.info())

# %%
# statistical summary
print(df.describe())

# %%
# rename column
df.rename(columns={"Sex": "gender"}, inplace=True)

# check columns
print(df.columns)

# %%
# problem 1: total survived based on gender
x = df.groupby('gender')['Survived'].sum()

# print result
print(x)

# %%
# problem 1: total survived based on gender
x = df.groupby('gender')['Survived'].sum()
print('People survived : \n',x)

# %%
#check missing the values
df.isnull().sum()

# %%
#cleaning
df['Age'].fillna(df['Age'].median(), inplace=True)
print(df.head(500))

# %%
# overall survival rate
df['Survived'].mean()

# %%
# survival by class
df.groupby('Pclass')['Survived'].mean()

# %%
#cleaning
df['Age'] = df['Age'].fillna(df['Age'].median(), inplace=True)
print(df.isnull().sum())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
print(df.isnull().sum())

# %%
# Drop Cabin column
df.drop(columns=['Cabin'], inplace=True)
print(df.isnull().sum())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.to_csv('titanic_cleaned.csv',index=False)

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
